# %%
import pandas as pd

# %%
parent_parameters = pd.read_csv('Datasets/parent-parameters.csv', index_col='Unnamed: 0')
parent_parameters
# Out:
#     ID        pl_name  pl_massj  pl_massjerr1  pl_massjerr2  pl_radj
# 0   AA  Kepler-1704 b     4.160         0.290        -0.280    1.066  \
# 1   AB     TOI-2180 b     2.755         0.087        -0.081    1.010
# 2   AC     KOI-3680 b     1.930         0.190        -0.210    0.990
# 3   AD     TOI-5542 b     1.320         0.100        -0.100    1.009
# 4   AE      NGTS-20 b     2.980         0.160        -0.150    1.070
# ..  ..            ...       ...           ...           ...      ...
# 95  DR      HD 2685 b     1.170         0.120        -0.120    1.440
# 96  DS     HAT-P-21 b     3.970         0.130        -0.130    1.024
# 97  DT     HAT-P-21 b     4.063         0.161        -0.161    1.024
# 98  DU      NGTS-13 b     4.840         0.440        -0.440    1.142
# 99  DV        K2-30 b     0.623         0.031        -0.031    1.196
#
#     pl_radjerr1  pl_radjerr2   pl_orbper  pl_orbpererr1  ...  st_mass
# ...

# %%
sum((parent_parameters['pl_orbper'].values<3))
# Out:
# 0

# %%
non_ringed_parameters = pd.read_csv('Datasets/non-ringed-parameters.csv', index_col='Unnamed: 0')
non_ringed_parameters
# Out:
#             ID  pl_massj   pl_radj  pl_orbsmax  pl_orbeccen  pl_orblper
# 0          AA0  4.175728  1.052813    2.017734     0.896938   83.168296  \
# 1          AB0  2.949314  1.029636    0.820094     0.373081  -45.826198
# 2          AC0  2.092102  0.972406    0.552081     0.472694  153.424202
# 3          AD0  1.283995  1.043554    0.311489     0.053451   20.541648
# 4          AE0  3.182136  1.095048    0.306745     0.451612   61.948883
# ...        ...       ...       ...         ...          ...         ...
# 199995  DR1999  1.321975  1.538187    0.057576     0.093418  194.120819
# 199996  DS1999  3.754643  0.837276    0.049894     0.215880  303.790322
# 199997  DT1999  4.059277  1.269735    0.049751     0.230721  307.892732
# 199998  DU1999  4.431885  1.164566    0.054600     0.075259 -142.445364
# 199999  DV1999  0.595582  1.199274    0.050188     0.068391   71.321501
#
#         pl_orbincl   st_mass    st_rad  pl_orbper_secs  transit_exists
# ...

# %%
sum((non_ringed_parameters['pl_orbper_secs'].values/3600/24)<3)
# Out:
# 8

# %%
ringed_parameters = pd.read_csv('Datasets/ringed-parameters.csv', index_col='Unnamed: 0')
ringed_parameters
# Out:
#       ID   pl_massj   pl_radj  pl_orbsmax  pl_orbeccen  pl_orblper
# 0    AA0   4.137400  1.009651    2.027940     0.911932   85.551920  \
# 1    AB0   2.730117  1.002185    0.822073     0.384047  -46.624087
# 2    AC0   1.915337  1.021806    0.542905     0.535406  151.030632
# 3    AD0   1.269682  0.985873    0.350371     0.009398  225.742541
# 4    AE0   2.818091  1.066083    0.317489     0.433645   70.230338
# ..   ...        ...       ...         ...          ...         ...
# 529  DK9   2.723544  0.951171    0.050621     0.087221   65.178587
# 530  DQ9  11.266023  1.565943    0.058918     0.420994  162.305366
# 531  DS9   3.980075  0.988901    0.049008     0.205482  305.016293
# 532  DT9   3.907599  1.258358    0.049917     0.245818  306.576571
# 533  DU9   4.812490  1.146517    0.055421     0.124669 -162.523636
#
#      pl_orbincl   st_mass    st_rad  pl_volume_m**3  pl_rho_kg/m**3
# 0     89.236140  1.117711  1.764484    1.473121e+24     5331.078919  \
# ...

# %%
sum((ringed_parameters['pl_orbper_secs'].values/3600/24)<3)
# Out:
# 0
